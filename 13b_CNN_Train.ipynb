# %% [markdown]
# <a href="https://colab.research.google.com/github/sergioGarcia91/ML_Carolina_Bays/blob/main/13b_CNN_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Start

# %%
# !pip install tables
# Out:
# Requirement already satisfied: tables in /usr/local/lib/python3.11/dist-packages (3.10.2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from tables) (2.0.2)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.11/dist-packages (from tables) (2.10.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tables) (24.2)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from tables) (9.0.0)
# Requirement already satisfied: blosc2>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from tables) (3.3.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from tables) (4.13.2)
# Requirement already satisfied: ndindex in /usr/local/lib/python3.11/dist-packages (from blosc2>=2.3.0->tables) (1.9.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from blosc2>=2.3.0->tables) (1.1.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from blosc2>=2.3.0->tables) (4.3.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from blosc2>=2.3.0->tables) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->blosc2>=2.3.0->tables) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->blosc2>=2.3.0->tables) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->blosc2>=2.3.0->tables) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->blosc2>=2.3.0->tables) (2025.4.26)

# %%
import numpy as np
import os
import time
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import h5py
import multiprocessing
import joblib

from sklearn.model_selection import train_test_split

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, TensorDataset

# Verificar si CUDA (GPU) está disponible
if torch.cuda.is_available():
    print(f"GPU disponible: {torch.cuda.get_device_name(0)}")
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
else:
    print("GPU no disponible, usando CPU.")
# Out:
# GPU disponible: NVIDIA A100-SXM4-40GB

# %%
device
# Out:
# device(type='cuda')

# %%
# Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Change Font of the Figures

# %%
# !wget https://github.com/justrajdeep/fonts/raw/master/Times%20New%20Roman.ttf
# Out:
# --2025-05-20 12:12:56--  https://github.com/justrajdeep/fonts/raw/master/Times%20New%20Roman.ttf
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/justrajdeep/fonts/master/Times%20New%20Roman.ttf [following]
# --2025-05-20 12:12:56--  https://raw.githubusercontent.com/justrajdeep/fonts/master/Times%20New%20Roman.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 834452 (815K) [application/octet-stream]
# Saving to: ‘Times New Roman.ttf’
#
# Times New Roman.ttf 100%[===================>] 814.89K  --.-KB/s    in 0.05s
#
# 2025-05-20 12:12:56 (14.5 MB/s) - ‘Times New Roman.ttf’ saved [834452/834452]

# %%
import matplotlib.font_manager as fm

# %%
# Path to the custom font
font_path = 'Times New Roman.ttf'

# Add the font to the Matplotlib font manager
font_prop = fm.FontProperties(fname=font_path)
fm.fontManager.addfont(font_path)

# Get the font name to use in rcParams
font_name = font_prop.get_name()
font_name
# Out:
# 'Times New Roman'

# %%
plt.rcParams['font.family'] = font_name

# %% [markdown]
# # Funtions

# %%
# 2. Definir la arquitectura del modelo con inicialización personalizada
class CNN(nn.Module):
  def __init__(self):
    super(CNN, self).__init__()
    self.conv_layers = nn.Sequential(
      nn.Conv2d(7, 32, kernel_size=3, padding=1),
      nn.ReLU(),
      nn.Conv2d(32, 32, kernel_size=3, padding=1),
      nn.ReLU(),
      nn.MaxPool2d(2),

      nn.Conv2d(32, 64, kernel_size=3, padding=1),
      nn.ReLU(),
      nn.Conv2d(64, 64, kernel_size=3, padding=1),
      nn.ReLU(),

      nn.Conv2d(64, 128, kernel_size=3, padding=1),
      nn.ReLU(),
      nn.Conv2d(128, 128, kernel_size=3, padding=1),
      nn.ReLU(),
      nn.MaxPool2d(2)
    )

    self.fc_layers = nn.Sequential(
      nn.Flatten(),
      nn.Linear(128 * 16 * 16, 128),  # Ajuste de tamaño
      nn.ReLU(),
      nn.Linear(128, 10)
    )

  def forward(self, x):
    x = self.conv_layers(x)
    x = self.fc_layers(x)
    return x

# 4. Función de entrenamiento
def train(model, train_loader, val_loader, criterion, optimizer, epochs=20):
    for epoch in range(epochs):
        running_loss = 0.0
        correct = 0
        total = 0
        model.train()

        for data in train_loader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device) # mover a GPU
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_acc = 100 * correct / total
        train_loss = running_loss / len(train_loader)

        # Validación después de cada época
        val_loss, val_acc = validate(model, val_loader, criterion)

        # Guardar las métricas
        train_acc_history.append(train_acc)
        val_acc_history.append(val_acc)
        train_loss_history.append(train_loss)
        val_loss_history.append(val_loss)

        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.2f}%, Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc:.2f}%")

# 5. Función de validación
def validate(model, val_loader, criterion):
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for data in val_loader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device) # mover a GPU
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    val_acc = 100 * correct / total
    val_loss /= len(val_loader)
    return val_loss, val_acc

# %% [markdown]
# # Load Data

# %%
path_save_h5 = '/content/drive/MyDrive/UIS/Doctorado_UIS2198589/1_semestre/TopicosAvanzadosGeofisica/FC_CarolinaBais/Dataset_h5'

h5_file = os.listdir(path_save_h5)
h5_file
# Out:
# ['dataset_AOI_01_32x32.h5',
#  'dataset_AOI_02_32x32.h5',
#  'dataset_AOI_03_32x32.h5',
#  'dataset_AOI_04_32x32.h5',
#  'dataset_AOI_02_64x64.h5',
#  'dataset_AOI_01_64x64.h5',
#  'dataset_AOI_03_64x64.h5',
#  'dataset_AOI_04_64x64.h5']

# %%
# Abrir archivo en modo lectura
with h5py.File(os.path.join(path_save_h5,'dataset_AOI_01_64x64.h5'), 'r') as f:
    # Ver todas las claves del archivo (datasets o grupos)
    print("Keys:", list(f.keys()))

    # Acceder a un dataset específico
    data_X_1 = f['AOI_01_X'][:]
    data_y_1 = f['AOI_01_FC_percentaje'][:]
    print(data_X_1.shape, data_y_1.dtype)

# Abrir archivo en modo lectura
with h5py.File(os.path.join(path_save_h5,'dataset_AOI_03_64x64.h5'), 'r') as f:
    # Ver todas las claves del archivo (datasets o grupos)
    print("Keys:", list(f.keys()))

    # Acceder a un dataset específico
    data_X_2 = f['AOI_03_X'][:]
    data_y_2 = f['AOI_03_FC_percentaje'][:]
    print(data_X_2.shape, data_y_2.dtype)

data_X = np.concatenate((data_X_1, data_X_2), axis=0)
data_y = np.concatenate((data_y_1, data_y_2), axis=0)
print(data_X.shape, data_y.shape)
# Out:
# Keys: ['AOI_01_FC_percentaje', 'AOI_01_X', 'AOI_01_y']
# (94500, 7, 64, 64) float64
# Keys: ['AOI_03_FC_percentaje', 'AOI_03_X', 'AOI_03_y']
# (94500, 7, 64, 64) float64
# (189000, 7, 64, 64) (189000,)

# %%
data_y.max()
# Out:
# np.float64(98.3642578125)

# %%
filter_y = data_y >= 1 # tomar las que el 1% sea FC
data_y = np.zeros(data_y.shape)
data_y[filter_y] = 1
data_y = data_y.reshape(-1, 1)
data_y
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])

# %%
data_X.shape, data_y.shape
# Out:
# ((189000, 7, 64, 64), (189000, 1))

# %%
data_y.sum()
# Out:
# np.float64(82511.0)

# %% [markdown]
# ## Split

# %%
X_train, X_test, y_train, y_test = train_test_split(data_X,
                                                    data_y,
                                                    test_size=0.2,
                                                    random_state=42)

# %%
X_train = torch.tensor(X_train)
y_train = torch.tensor(y_train, dtype=torch.long).squeeze()

print(X_train.shape, y_train.shape)
# Out:
# torch.Size([151200, 7, 64, 64]) torch.Size([151200])

# %%
X_test = torch.tensor(X_test)
y_test = torch.tensor(y_test, dtype=torch.long).squeeze()

print(X_test.shape, y_test.shape)
# Out:
# torch.Size([37800, 7, 64, 64]) torch.Size([37800])

# %%
# Agrupar en un dataset
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

# %%
# Inicializar el modelo y aplicar la inicialización personalizada
model = CNN().to(device) # mover a GPU

# 3. Definir la función de pérdida y el optimizador
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Listas para guardar las métricas
train_acc_history = []
val_acc_history = []
train_loss_history = []
val_loss_history = []

# %%
train_loader = DataLoader(train_dataset, batch_size=256,# 32 con CPU GPU 01... 256 con GPU 02
                          shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=256,# 32 con CPU GPU 01 ... 256 con GPU 02
                         shuffle=False, num_workers=2)

# %% [markdown]
# ## Train

# %%
# 6. Entrenar el modelo
train(model, train_loader, test_loader, criterion, optimizer, epochs=100)
# 100 iteraciones eran mucho ... a la proxima solo 50
# Out:
# Epoch 1/100, Train Loss: 0.8302, Train Accuracy: 54.47%, Val Loss: 0.6838, Val Accuracy: 56.33%
# Epoch 2/100, Train Loss: 0.6831, Train Accuracy: 56.29%, Val Loss: 0.6764, Val Accuracy: 56.33%
# Epoch 3/100, Train Loss: 0.6536, Train Accuracy: 58.19%, Val Loss: 0.6202, Val Accuracy: 63.66%
# Epoch 4/100, Train Loss: 0.4938, Train Accuracy: 75.82%, Val Loss: 0.4415, Val Accuracy: 81.15%
# Epoch 5/100, Train Loss: 0.3628, Train Accuracy: 84.57%, Val Loss: 0.3656, Val Accuracy: 88.02%
# Epoch 6/100, Train Loss: 0.3289, Train Accuracy: 86.37%, Val Loss: 0.2634, Val Accuracy: 90.00%
# Epoch 7/100, Train Loss: 0.3502, Train Accuracy: 84.36%, Val Loss: 0.2760, Val Accuracy: 89.52%
# Epoch 8/100, Train Loss: 0.5586, Train Accuracy: 67.95%, Val Loss: 0.5779, Val Accuracy: 65.46%
# Epoch 9/100, Train Loss: 0.5459, Train Accuracy: 69.09%, Val Loss: 0.5732, Val Accuracy: 65.67%
# Epoch 10/100, Train Loss: 0.3717, Train Accuracy: 82.22%, Val Loss: 0.7064, Val Accuracy: 65.57%
# Epoch 11/100, Train Loss: 0.4112, Train Accuracy: 79.62%, Val Loss: 0.2559, Val Accuracy: 89.99%
# Epoch 12/100, Train Loss: 0.3284, Train Accuracy: 85.15%, Val Loss: 0.2294, Val Accuracy: 91.28%
# Epoch 13/100, Train Loss: 0.2864, Train Accuracy: 87.72%, Val Loss: 0.2159, Val Accuracy: 91.49%
# Epoch 14/100, Train Loss: 0.2720, Train Accuracy: 88.34%, Val Loss: 0.1869, Val Accuracy: 93.22%
# Epoch 15/100, Train Loss: 0.2765, Train Accuracy: 88.05%, Val Loss: 0.1689, Val Accuracy: 94.47%
# Epoch 16/100, Train Loss: 0.2941, Train Accuracy: 86.54%, Val Loss: 0.3968, Val Accuracy: 80.61%
# Epoch 17/100, Train Loss: 0.1894, Train Accuracy: 93.44%, Val Loss: 0.1382, Val Accuracy: 96.24%
# Epoch 18/100, Train Loss: 0.1643, Train Accuracy: 94.65%, Val Loss: 0.1285, Val Accuracy: 96.56%
# Epoch 19/100, Train Loss: 0.1270, Train Accuracy: 96.65%, Val Loss: 0.1414, Val Accuracy: 96.22%
# Epoch 20/100, Train Loss: 0.1212, Train Accuracy: 96.91%, Val Loss: 0.1159, Val Accuracy: 97.10%
# Epoch 21/100, Train Loss: 0.2812, Train Accuracy: 87.35%, Val Loss: 0.1889, Val Accuracy: 93.16%
# Epoch 22/100, Train Loss: 0.1369, Train Accuracy: 96.05%, Val Loss: 0.1208, Val Accuracy: 96.93%
# Epoch 23/100, Train Loss: 0.1198, Train Accuracy: 96.82%, Val Loss: 0.1150, Val Accuracy: 97.24%
# Epoch 24/100, Train Loss: 0.1136, Train Accuracy: 97.11%, Val Loss: 0.1159, Val Accuracy: 97.30%
# Epoch 25/100, Train Loss: 0.1120, Train Accuracy: 97.15%, Val Loss: 0.1098, Val Accuracy: 97.30%
# Epoch 26/100, Train Loss: 0.1098, Train Accuracy: 97.21%, Val Loss: 0.1095, Val Accuracy: 97.32%
# Epoch 27/100, Train Loss: 0.1095, Train Accuracy: 97.26%, Val Loss: 0.1192, Val Accuracy: 97.30%
# Epoch 28/100, Train Loss: 0.1103, Train Accuracy: 97.23%, Val Loss: 0.1094, Val Accuracy: 97.43%
# Epoch 29/100, Train Loss: 0.1084, Train Accuracy: 97.33%, Val Loss: 0.1129, Val Accuracy: 97.37%
# Epoch 30/100, Train Loss: 0.1087, Train Accuracy: 97.31%, Val Loss: 0.1114, Val Accuracy: 97.43%
# Epoch 31/100, Train Loss: 0.1077, Train Accuracy: 97.34%, Val Loss: 0.1077, Val Accuracy: 97.39%
# Epoch 32/100, Train Loss: 0.1076, Train Accuracy: 97.33%, Val Loss: 0.1170, Val Accuracy: 97.23%
# Epoch 33/100, Train Loss: 0.1062, Train Accuracy: 97.35%, Val Loss: 0.1057, Val Accuracy: 97.43%
# Epoch 34/100, Train Loss: 0.1067, Train Accuracy: 97.34%, Val Loss: 0.1080, Val Accuracy: 97.43%
# Epoch 35/100, Train Loss: 0.1054, Train Accuracy: 97.36%, Val Loss: 0.1069, Val Accuracy: 97.43%
# Epoch 36/100, Train Loss: 0.1062, Train Accuracy: 97.33%, Val Loss: 0.1054, Val Accuracy: 97.43%
# Epoch 37/100, Train Loss: 0.1056, Train Accuracy: 97.35%, Val Loss: 0.1063, Val Accuracy: 97.43%
# Epoch 38/100, Train Loss: 0.1054, Train Accuracy: 97.35%, Val Loss: 0.1122, Val Accuracy: 97.43%
# Epoch 39/100, Train Loss: 0.1048, Train Accuracy: 97.36%, Val Loss: 0.1096, Val Accuracy: 97.25%
# Epoch 40/100, Train Loss: 0.1047, Train Accuracy: 97.36%, Val Loss: 0.1089, Val Accuracy: 97.43%
# Epoch 41/100, Train Loss: 0.1045, Train Accuracy: 97.36%, Val Loss: 0.1046, Val Accuracy: 97.43%
# Epoch 42/100, Train Loss: 0.1040, Train Accuracy: 97.35%, Val Loss: 0.1047, Val Accuracy: 97.43%
# Epoch 43/100, Train Loss: 0.1037, Train Accuracy: 97.36%, Val Loss: 0.1073, Val Accuracy: 97.43%
# Epoch 44/100, Train Loss: 0.1039, Train Accuracy: 97.36%, Val Loss: 0.1054, Val Accuracy: 97.43%
# Epoch 45/100, Train Loss: 0.1039, Train Accuracy: 97.36%, Val Loss: 0.1064, Val Accuracy: 97.43%
# Epoch 46/100, Train Loss: 0.1038, Train Accuracy: 97.36%, Val Loss: 0.1070, Val Accuracy: 97.43%
# Epoch 47/100, Train Loss: 0.1036, Train Accuracy: 97.36%, Val Loss: 0.1068, Val Accuracy: 97.43%
# Epoch 48/100, Train Loss: 0.1036, Train Accuracy: 97.36%, Val Loss: 0.1042, Val Accuracy: 97.43%
# Epoch 49/100, Train Loss: 0.1033, Train Accuracy: 97.36%, Val Loss: 0.1042, Val Accuracy: 97.43%
# Epoch 50/100, Train Loss: 0.1031, Train Accuracy: 97.36%, Val Loss: 0.1045, Val Accuracy: 97.43%
# Epoch 51/100, Train Loss: 0.1030, Train Accuracy: 97.36%, Val Loss: 0.1065, Val Accuracy: 97.43%
# Epoch 52/100, Train Loss: 0.1028, Train Accuracy: 97.36%, Val Loss: 0.1031, Val Accuracy: 97.43%
# Epoch 53/100, Train Loss: 0.1028, Train Accuracy: 97.36%, Val Loss: 0.1044, Val Accuracy: 97.43%
# Epoch 54/100, Train Loss: 0.1029, Train Accuracy: 97.36%, Val Loss: 0.1049, Val Accuracy: 97.38%
# Epoch 55/100, Train Loss: 0.1029, Train Accuracy: 97.36%, Val Loss: 0.1045, Val Accuracy: 97.43%
# Epoch 56/100, Train Loss: 0.1027, Train Accuracy: 97.36%, Val Loss: 0.1034, Val Accuracy: 97.43%
# Epoch 57/100, Train Loss: 0.1026, Train Accuracy: 97.36%, Val Loss: 0.1032, Val Accuracy: 97.43%
# Epoch 58/100, Train Loss: 0.1025, Train Accuracy: 97.36%, Val Loss: 0.1036, Val Accuracy: 97.43%
# Epoch 59/100, Train Loss: 0.1024, Train Accuracy: 97.36%, Val Loss: 0.1038, Val Accuracy: 97.43%
# Epoch 60/100, Train Loss: 0.1023, Train Accuracy: 97.36%, Val Loss: 0.1040, Val Accuracy: 97.43%
# Epoch 61/100, Train Loss: 0.1023, Train Accuracy: 97.37%, Val Loss: 0.1043, Val Accuracy: 97.43%
# Epoch 62/100, Train Loss: 0.1024, Train Accuracy: 97.36%, Val Loss: 0.1034, Val Accuracy: 97.43%
# Epoch 63/100, Train Loss: 0.1025, Train Accuracy: 97.35%, Val Loss: 0.1037, Val Accuracy: 97.43%
# Epoch 64/100, Train Loss: 0.1022, Train Accuracy: 97.36%, Val Loss: 0.1041, Val Accuracy: 97.43%
# Epoch 65/100, Train Loss: 0.1020, Train Accuracy: 97.36%, Val Loss: 0.1039, Val Accuracy: 97.43%
# Epoch 66/100, Train Loss: 0.1022, Train Accuracy: 97.36%, Val Loss: 0.1069, Val Accuracy: 97.43%
# Epoch 67/100, Train Loss: 0.1017, Train Accuracy: 97.37%, Val Loss: 0.1033, Val Accuracy: 97.43%
# Epoch 68/100, Train Loss: 0.1020, Train Accuracy: 97.36%, Val Loss: 0.1089, Val Accuracy: 97.28%
# Epoch 69/100, Train Loss: 0.1020, Train Accuracy: 97.36%, Val Loss: 0.1056, Val Accuracy: 97.43%
# Epoch 70/100, Train Loss: 0.1018, Train Accuracy: 97.37%, Val Loss: 0.1030, Val Accuracy: 97.43%
# Epoch 71/100, Train Loss: 0.1016, Train Accuracy: 97.36%, Val Loss: 0.1038, Val Accuracy: 97.43%
# Epoch 72/100, Train Loss: 0.1018, Train Accuracy: 97.36%, Val Loss: 0.1034, Val Accuracy: 97.43%
# Epoch 73/100, Train Loss: 0.1016, Train Accuracy: 97.37%, Val Loss: 0.1107, Val Accuracy: 97.21%
# Epoch 74/100, Train Loss: 0.1017, Train Accuracy: 97.36%, Val Loss: 0.1037, Val Accuracy: 97.43%
# Epoch 75/100, Train Loss: 0.1016, Train Accuracy: 97.36%, Val Loss: 0.1029, Val Accuracy: 97.43%
# Epoch 76/100, Train Loss: 0.1014, Train Accuracy: 97.36%, Val Loss: 0.1037, Val Accuracy: 97.43%
# Epoch 77/100, Train Loss: 0.1014, Train Accuracy: 97.37%, Val Loss: 0.1063, Val Accuracy: 97.43%
# Epoch 78/100, Train Loss: 0.1015, Train Accuracy: 97.37%, Val Loss: 0.1027, Val Accuracy: 97.43%
# Epoch 79/100, Train Loss: 0.1013, Train Accuracy: 97.36%, Val Loss: 0.1029, Val Accuracy: 97.43%
# Epoch 80/100, Train Loss: 0.1013, Train Accuracy: 97.37%, Val Loss: 0.1032, Val Accuracy: 97.43%
# Epoch 81/100, Train Loss: 0.1014, Train Accuracy: 97.36%, Val Loss: 0.1054, Val Accuracy: 97.43%
# Epoch 82/100, Train Loss: 0.1013, Train Accuracy: 97.37%, Val Loss: 0.1030, Val Accuracy: 97.43%
# Epoch 83/100, Train Loss: 0.1014, Train Accuracy: 97.36%, Val Loss: 0.1039, Val Accuracy: 97.43%
# Epoch 84/100, Train Loss: 0.1015, Train Accuracy: 97.36%, Val Loss: 0.1052, Val Accuracy: 97.43%
# Epoch 85/100, Train Loss: 0.1014, Train Accuracy: 97.36%, Val Loss: 0.1043, Val Accuracy: 97.43%
# Epoch 86/100, Train Loss: 0.1012, Train Accuracy: 97.37%, Val Loss: 0.1033, Val Accuracy: 97.43%
# Epoch 87/100, Train Loss: 0.1011, Train Accuracy: 97.36%, Val Loss: 0.1029, Val Accuracy: 97.43%
# Epoch 88/100, Train Loss: 0.1010, Train Accuracy: 97.37%, Val Loss: 0.1031, Val Accuracy: 97.43%
# Epoch 89/100, Train Loss: 0.1010, Train Accuracy: 97.37%, Val Loss: 0.1033, Val Accuracy: 97.43%
# Epoch 90/100, Train Loss: 0.1011, Train Accuracy: 97.37%, Val Loss: 0.1027, Val Accuracy: 97.43%
# Epoch 91/100, Train Loss: 0.1010, Train Accuracy: 97.37%, Val Loss: 0.1043, Val Accuracy: 97.43%
# Epoch 92/100, Train Loss: 0.1012, Train Accuracy: 97.36%, Val Loss: 0.1027, Val Accuracy: 97.43%
# Epoch 93/100, Train Loss: 0.1010, Train Accuracy: 97.37%, Val Loss: 0.1030, Val Accuracy: 97.43%
# Epoch 94/100, Train Loss: 0.1007, Train Accuracy: 97.37%, Val Loss: 0.1027, Val Accuracy: 97.43%
# Epoch 95/100, Train Loss: 0.1011, Train Accuracy: 97.36%, Val Loss: 0.1032, Val Accuracy: 97.43%
# Epoch 96/100, Train Loss: 0.1011, Train Accuracy: 97.36%, Val Loss: 0.1027, Val Accuracy: 97.43%
# Epoch 97/100, Train Loss: 0.1009, Train Accuracy: 97.36%, Val Loss: 0.1035, Val Accuracy: 97.43%
# Epoch 98/100, Train Loss: 0.1008, Train Accuracy: 97.37%, Val Loss: 0.1027, Val Accuracy: 97.43%
# Epoch 99/100, Train Loss: 0.1005, Train Accuracy: 97.37%, Val Loss: 0.1026, Val Accuracy: 97.43%
# Epoch 100/100, Train Loss: 0.1009, Train Accuracy: 97.37%, Val Loss: 0.1026, Val Accuracy: 97.43%

# %%
pathSavePlots = '/content/drive/MyDrive/UIS/Doctorado_UIS2198589/1_semestre/TopicosAvanzadosGeofisica/FC_CarolinaBais/Figures_Models/'

# %%
# 7. Graficar precisión y pérdida
fig = plt.figure(figsize=(10,5))

# Precisión
ax = fig.add_subplot(1, 2, 1)
ax.plot(train_acc_history, label='Train Accuracy')
ax.plot(val_acc_history, label='Validation Accuracy')
ax.set_xlabel('Epochs')
ax.set_ylabel('Accuracy')
ax.legend()
ax.grid(color='grey', ls='--', alpha=0.8)

# Pérdida
ax = fig.add_subplot(1, 2, 2)
ax.plot(train_loss_history, label='Train Loss')
ax.plot(val_loss_history, label='Validation Loss')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.legend()
ax.grid(color='grey', ls='--', alpha=0.8)

plt.savefig(pathSavePlots + f'Training_CNN_GPU_03.png',
            dpi=500,
            bbox_inches = 'tight',
            pad_inches=0.25)

plt.show()

# %% [markdown]
# # Save model

# %%
path_save_models = '/content/drive/MyDrive/UIS/Doctorado_UIS2198589/1_semestre/TopicosAvanzadosGeofisica/FC_CarolinaBais/ML_models/'
name_model = 'model_CNN_GPU_03.pth' # 20 epochs
# el modelo 03 toma el AOI 1 y AOI 3 para el entrenamiento

torch.save(model.state_dict(), path_save_models + name_model)

# %%
os.listdir('/content/drive/MyDrive/UIS/Doctorado_UIS2198589/1_semestre/TopicosAvanzadosGeofisica/FC_CarolinaBais/ML_models')
# Out:
# ['model_RegLog_002.pkl',
#  'model_RegLog_003.pkl',
#  'model_RegLog_004.pkl',
#  'model_RegLog_005.pkl',
#  'model_RegLog_006.pkl',
#  'model_RegLog_007.pkl',
#  'model_RegLog_008.pkl',
#  'model_RegLog_009.pkl',
#  'model_RegLog_010.pkl',
#  'model_RegLog_001.pkl',
#  'model_RegLog_011.pkl',
#  'model_RegLog_012.pkl',
#  'model_RegLog_013.pkl',
#  'model_RegLog_014.pkl',
#  'model_RegLog_015.pkl',
#  'model_RegLog_016.pkl',
#  'model_RegLog_017.pkl',
#  'model_RegLog_018.pkl',
#  'model_RegLog_019.pkl',
#  'model_RegLog_020.pkl',
#  'model_RegLog_021.pkl',
#  'model_RegLog_022.pkl',
#  'model_RegLog_023.pkl',
#  'model_RegLog_024.pkl',
#  'model_RegLog_025.pkl',
#  'model_RegLog_026.pkl',
#  'model_RegLog_027.pkl',
#  'model_RegLog_028.pkl',
#  'model_RegLog_029.pkl',
#  'model_RegLog_030.pkl',
#  'df_30models_LogReg.csv',
#  'model_RandForest_001.pkl',
#  'model_RandForest_002.pkl',
#  'model_RandForest_003.pkl',
#  'model_RandForest_004.pkl',
#  'model_RandForest_005.pkl',
#  'model_RandForest_006.pkl',
#  'model_RandForest_007.pkl',
#  'model_RandForest_008.pkl',
#  'model_RandForest_009.pkl',
#  'model_RandForest_010.pkl',
#  'model_RandForest_011.pkl',
#  'model_RandForest_012.pkl',
#  'model_RandForest_013.pkl',
#  'model_RandForest_014.pkl',
#  'model_RandForest_015.pkl',
#  'model_RandForest_016.pkl',
#  'model_RandForest_017.pkl',
#  'model_RandForest_018.pkl',
#  'model_RandForest_019.pkl',
#  'model_RandForest_020.pkl',
#  'model_RandForest_021.pkl',
#  'model_RandForest_022.pkl',
#  'model_RandForest_023.pkl',
#  'model_RandForest_024.pkl',
#  'model_RandForest_025.pkl',
#  'model_RandForest_026.pkl',
#  'model_RandForest_027.pkl',
#  'model_RandForest_028.pkl',
#  'model_RandForest_029.pkl',
#  'model_RandForest_030.pkl',
#  'df_30models_RandForest.csv',
#  'model_MLPClassifier_001.pkl',
#  'model_MLPClassifier_002.pkl',
#  'df_30models_RandForest_01.csv',
#  'df_30models_LogReg_01.csv',
#  'model_MLPClassifier_003.pkl',
#  'model_MLPClassifier_004.pkl',
#  'model_MLPClassifier_005.pkl',
#  'model_MLPClassifier_006.pkl',
#  'model_MLPClassifier_007.pkl',
#  'model_MLPClassifier_008.pkl',
#  'model_MLPClassifier_009.pkl',
#  'model_MLPClassifier_010.pkl',
#  'df_30model_MLPClassifier.csv',
#  'df_30model_MLPClassifier_01.csv',
#  'df_order_features.csv',
#  'model_MLP_Classifier_001b.pkl',
#  'model_MLP_Classifier_002b.pkl',
#  'model_MLP_Classifier_003b.pkl',
#  'model_MLP_Classifier_004b.pkl',
#  'model_MLP_Classifier_005b.pkl',
#  'df_Xmodel_MLPClassifier_b.csv',
#  'df_Xmodel_MLPClassifier_b_01.csv',
#  'df_70models_ML.csv',
#  'metrics_models_test.csv',
#  'metrics_models_test_SG.csv',
#  'df_order_features_SG.csv',
#  'df_order_features_SG_excel.xlsx',
#  'model_CNN_CPU_01.pth',
#  'model_CNN_GPU_01.pth',
#  'model_CNN_GPU_02.pth',
#  'model_CNN_GPU_03.pth']

# %% [markdown]
# # End
