# %% [markdown]
# <a href="https://colab.research.google.com/github/sergioGarcia91/ML_Carolina_Bays/blob/main/03b_Plot_Dataset_h5_64x64.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook aims to load and visualize the data stored in HDF5 (.h5) files.

# %% [markdown]
# # Start

# %%
import numpy as np
import os
import time
import matplotlib.pyplot as plt
import h5py

from IPython.display import clear_output

# %%
# Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Funtions

# %% [markdown]
# ## get_rgb

# %%
def get_rgb(tif):
  rgb_image = np.dstack((tif[3],
                         tif[2],
                         tif[1]))
  return rgb_image

# %% [markdown]
# ## normalize

# %%
def normalize(img, min_percent=2, max_percent=98):
  # Adjusts the image contrast using percentiles.
  p_min, p_max = np.percentile(img, (min_percent, max_percent))
  return np.clip((img - p_min) / (p_max - p_min), 0, 1)

# %% [markdown]
# # Path h5

# %%
path_save_h5 = '/content/drive/MyDrive/UIS/Doctorado_UIS2198589/1_semestre/TopicosAvanzadosGeofisica/FC_CarolinaBais/Dataset_h5'

h5_file = os.listdir(path_save_h5)
h5_file
# Out:
# ['dataset_AOI_01_32x32.h5',
#  'dataset_AOI_02_32x32.h5',
#  'dataset_AOI_03_32x32.h5',
#  'dataset_AOI_04_32x32.h5',
#  'dataset_AOI_02_64x64.h5',
#  'dataset_AOI_01_64x64.h5',
#  'dataset_AOI_03_64x64.h5']

# %% [markdown]
# ## F1

# %%
# read file 1
#f1 = h5py.File(os.path.join(path_save_h5, h5_file[0]), 'r')
f1 = h5py.File(os.path.join(path_save_h5, 'dataset_AOI_01_64x64.h5'), 'r')
f1
# Out:
# <HDF5 file "dataset_AOI_01_64x64.h5" (mode r)>

# %%
f1.attrs
# Out:
# <Attributes of HDF5 object at 137835755660176>

# %%
f1.keys()
# Out:
# <KeysViewHDF5 ['AOI_01_FC_percentaje', 'AOI_01_X', 'AOI_01_y']>

# %%
f1['AOI_01_X'].shape
# Out:
# (94500, 7, 64, 64)

# %%
f1['AOI_01_X'].shape
# Out:
# (94500, 7, 64, 64)

# %%
f1['AOI_01_X'][25:30].shape
# Out:
# (5, 7, 64, 64)

# %%
datos = np.array(f1['AOI_01_X'][25:30])
datos_reformateados = datos.transpose(0, 2, 3, 1).reshape(-1, 7)

# %%
datos.transpose(0, 2, 3, 1).shape
# Out:
# (5, 64, 64, 7)

# %%
datos.transpose(0, 2, 3, 1)[0][0][0]
# Out:
# array([0., 0., 0., 0., 0., 0., 0.], dtype=float32)

# %%
datos_reformateados.shape
# Out:
# (20480, 7)

# %%
imgs_of_interests = np.arange(0, f1['AOI_01_X'].shape[0], 10000)

for img_interest in imgs_of_interests:
  print(f'Image {img_interest}')
  X_ = f1['AOI_01_X'][img_interest]
  Y_ = f1['AOI_01_y'][img_interest]
  P_ = f1['AOI_01_FC_percentaje'][img_interest]

  fig, ax = plt.subplots(figsize=(5, 3), nrows=1, ncols=2)
  ax[0].imshow(normalize(get_rgb(X_)))  # Apply normalization
  ax[0].axis('off')
  ax[1].imshow(Y_, vmin=0, vmax=1)
  ax[1].axis('off')

  plt.suptitle(f'Image {img_interest} - FC:{P_:.2f}%', fontsize=10)
  plt.tight_layout()
  plt.show()
  print('\n')
# Out:
# Image 0
# Image 10000
# Image 20000
# Image 30000
# Image 40000
# Image 50000
# Image 60000
# Image 70000
# Image 80000
# Image 90000

# %% [markdown]
# ## F2

# %%
# read file 2
#f2 = h5py.File(os.path.join(path_save_h5, h5_file[1]), 'r')
f2 = h5py.File(os.path.join(path_save_h5, 'dataset_AOI_02_64x64.h5'), 'r')
f2
# Out:
# <HDF5 file "dataset_AOI_02_64x64.h5" (mode r)>

# %%
f2['AOI_02_X'].shape
# Out:
# (94500, 7, 64, 64)

# %%
imgs_of_interests = np.arange(0, f2['AOI_02_X'].shape[0], 10000)

for img_interest in imgs_of_interests:
  print(f'Image {img_interest}')
  X_ = f2['AOI_02_X'][img_interest]
  Y_ = f2['AOI_02_y'][img_interest]
  P_ = f2['AOI_02_FC_percentaje'][img_interest]

  fig, ax = plt.subplots(figsize=(5, 3), nrows=1, ncols=2)
  ax[0].imshow(normalize(get_rgb(X_)))  # Apply normalization
  ax[0].axis('off')
  ax[1].imshow(Y_, vmin=0, vmax=1)
  ax[1].axis('off')

  plt.suptitle(f'Image {img_interest} - FC:{P_:.2f}%', fontsize=10)
  plt.tight_layout()
  plt.show()
  print('\n')
# Out:
# Image 0
# Image 10000
# Image 20000
# Image 30000
# Image 40000
# Image 50000
# Image 60000
# Image 70000
# Image 80000
# Image 90000

# %% [markdown]
# ## F3

# %%
# read file 3
#f3 = h5py.File(os.path.join(path_save_h5, h5_file[2]), 'r')
f3 = h5py.File(os.path.join(path_save_h5, 'dataset_AOI_03_64x64.h5'), 'r')
f3
# Out:
# <HDF5 file "dataset_AOI_03_64x64.h5" (mode r)>

# %%
f3['AOI_03_X'].shape
# Out:
# (94500, 7, 64, 64)

# %%
imgs_of_interests = np.arange(0, f3['AOI_03_X'].shape[0], 10000)

for img_interest in imgs_of_interests:
  print(f'Image {img_interest}')
  X_ = f3['AOI_03_X'][img_interest]
  Y_ = f3['AOI_03_y'][img_interest]
  P_ = f3['AOI_03_FC_percentaje'][img_interest]

  fig, ax = plt.subplots(figsize=(5, 3), nrows=1, ncols=2)
  ax[0].imshow(normalize(get_rgb(X_)))  # Apply normalization
  ax[0].axis('off')
  ax[1].imshow(Y_, vmin=0, vmax=1)
  ax[1].axis('off')

  plt.suptitle(f'Image {img_interest} - FC:{P_:.2f}%', fontsize=10)
  plt.tight_layout()
  plt.show()
  print('\n')
# Out:
# Image 0
# Image 10000
# Image 20000
# Image 30000
# Image 40000
# Image 50000
# Image 60000
# Image 70000
# Image 80000
# Image 90000

# %% [markdown]
# ## F4

# %%
# read file 4
#f4 = h5py.File(os.path.join(path_save_h5, h5_file[3]), 'r')
f4 = h5py.File(os.path.join(path_save_h5, 'dataset_AOI_04_64x64.h5'), 'r')
f4
# Out:
# <HDF5 file "dataset_AOI_04_64x64.h5" (mode r)>

# %%
f4['AOI_04_X'].shape
# Out:
# (94500, 7, 64, 64)

# %%
imgs_of_interests = np.arange(0, f4['AOI_04_X'].shape[0], 10000)

for img_interest in imgs_of_interests:
  print(f'Image {img_interest}')
  X_ = f4['AOI_04_X'][img_interest]
  Y_ = f4['AOI_04_y'][img_interest]
  P_ = f4['AOI_04_FC_percentaje'][img_interest]

  fig, ax = plt.subplots(figsize=(5, 3), nrows=1, ncols=2)
  ax[0].imshow(normalize(get_rgb(X_)))  # Apply normalization
  ax[0].axis('off')
  ax[1].imshow(Y_, vmin=0, vmax=1)
  ax[1].axis('off')

  plt.suptitle(f'Image {img_interest} - FC:{P_:.2f}%', fontsize=10)
  plt.tight_layout()
  plt.show()
  print('\n')
# Out:
# Image 0
# Image 10000
# Image 20000
# Image 30000
# Image 40000
# Image 50000
# Image 60000
# Image 70000
# Image 80000
# Image 90000

# %% [markdown]
# # End
